# %%
import pandas as pd
df = pd.DataFrame(list(pd.read_json('user.status.json.gz').result))
print(set(df.testset))
df[df.testset == 'PRETESTS']
# Out:
# {'CHALLENGES', 'PRETESTS', 'TESTS2', 'TESTS', 'TESTS1'}
#              id  contestId  creationTimeSeconds  relativeTimeSeconds  \
# 53    240596220       1919           1704560457                 8757
# 54    240595580       1919           1704560352                 8652
# 55    240593866       1919           1704560078                 8378
# 56    240592997       1919           1704559940                 8240
# 57    240590983       1919           1704559599                 7899
# ...         ...        ...                  ...                  ...
# 2689     619051        106           1313770207                 4207
# 2691     616751        106           1313767112                 1112
# 2699     363997         71           1301414043                 3243
# 2702     362195         71           1301411186                  386
# 2725     258034         56           1295629846                 3646
#
#                                                 problem  \
# ...
